# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data.csv')
df.drop('Crawl Timestamp', axis=1, inplace=True)
df.drop('Uniq Id', axis=1, inplace=True) 

df.dropna(how='any',inplace=True)

# %%
for i in range(len(df)):
    if (type(df.iloc[i]['Key Skills']) is str):
        df.iloc[i]['Key Skills'] = df.iloc[i]['Key Skills'].split('|')
    if (type(df.iloc[i]['Location']) is str):
        locationToAdd = df.iloc[i]['Location'].split(',')
        for j in range (len(locationToAdd)):
            if (len(locationToAdd[j]) != 0):
                if (locationToAdd[j][0] == ' '):
                    locationToAdd[j] = locationToAdd[j][1:]
            locationToAdd[j] = locationToAdd[j].capitalize()
        df.iloc[i]['Location'] = locationToAdd
    if (type(df.iloc[i]['Functional Area']) is str):
        df.iloc[i]['Functional Area'] = df.iloc[i]['Functional Area'].split(',')
    if (type(df.iloc[i]['Industry']) is str):
        df.iloc[i]['Industry'] = df.iloc[i]['Industry'].split(',')
    if (type(df.iloc[i]['Role Category']) is str):
        df.iloc[i]['Role Category'] = df.iloc[i]['Role Category'].split('/') 
    if (type(df.iloc[i]['Role']) is str and len(df.iloc[i]['Role']) > 100) :
        df.iloc[i]['Role'] = 'N/A'
    df.iloc[i]['Role'] = df.iloc[i]['Role'].replace('/', ',')
    if not ("0 -" in df.iloc[i]['Job Experience Required'] and "10 -" not in df.iloc[i]['Job Experience Required'] and "20 -" not in df.iloc[i]['Job Experience Required']):
        df.iloc[i]['Job Experience Required'] = np.nan
df.dropna(how='any',inplace=True)

# %%
df.drop('Job Experience Required', axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)
df.to_csv('FilteredData.csv')

# %%
df.head(5)
# Out:
#                                            Job Title  \
# 0   Trainee Research/ Research Executive- Hi- Tec...
# 1                                  Technical Support
# 2     Sales- Fresher-for Leading Property Consultant
# 3   Looking For Trained Freshers in MS Dynamics C...
# 4             Business Development / Corporate Sales
#
#                      Job Salary  \
# 0   Not Disclosed by Recruiter
# 1      2,00,000 - 4,00,000 PA.
# 2      2,00,000 - 3,00,000 PA.
# 3   Not Disclosed by Recruiter
# 4      2,50,000 - 4,50,000 PA.
#
#                                           Key Skills  \
# 0  [ Computer science,  Fabrication,  Quality che...
# 1                               [ Technical Support]
# 2  [ channel partners,  real estate,  negotiation...
# 3  [ C#,  MS Dynamics CRM,  Microsoft Dynamics,  ...
# 4  [ lead generation,  business development,  cor...
#
#                                      Role Category     Location  \
# 0                                            [R&D]    [Gurgaon]
# 1  [Admin, Maintenance, Security, Datawarehousing]     [Mumbai]
# 2                                   [Retail Sales]  [Bengaluru]
# 3                           [Programming & Design]  [Hyderabad]
# 4                                   [Retail Sales]  [Delhi ncr]
#
#                                      Functional Area  \
# 0                        [Engineering Design ,  R&D]
# 1  [IT Software - Application Programming ,  Main...
# 2          [Sales ,  Retail ,  Business Development]
# 3  [IT Software - Application Programming ,  Main...
# 4          [Sales ,  Retail ,  Business Development]
#
#                             Industry                                Role
# 0           [Recruitment,  Staffing]                       R&D Executive
# 1  [IT-Software,  Software Services]          Technical Support Engineer
# 2           [Real Estate,  Property]             Sales Executive,Officer
# 3  [IT-Software,  Software Services]                  Software Developer
# 4  [IT-Software,  Software Services]  Sales,Business Development Manager

# %%
cities = []
for i in range (len(df)):
    for j in range (len(df.iloc[i]['Location'])):
        cities.append(df.iloc[i]['Location'][j])
cities.sort()
cities = list( dict.fromkeys(cities) )

# %%
len(cities)
# Out:
# 442

# %%
cities
# Out:
# ['',
#  '...more',
#  'Adilabad',
#  'Agartala',
#  'Agra',
#  'Ahmedabad',
#  'Ahmedabad (bapunagar',
#  'Ahmedabad (bodakdev) ',
#  'Ahmedabad (drive in road) ',
#  'Ahmedabad (kasindra) ',
#  'Ahmedabad (makarba) ',
#  'Ahmedabad (navrangpura) ',
#  'Ahmedabad (prahlad nagar) ',
#  'Ahmedabad (shilaj',
#  'Ahmedabad (shyamal cross road',
#  'Ahmedabad (vastrapur) ',
#  'Ahmednagar',
#  'Ajmer',
#  'Akola',
#  'Aligarh',
#  'Allahabad',
#  'Ambala',
#  'Amritsar',
#  'Anand',
#  'Anantapur',
#  'Andhrapradesh other',
#  'Ankleshwar',
#  'Anuppur',
#  'Asansol',
#  'Asarwa',
#  'Aurangabad',
#  'Bahraich',
#  'Balasore',
#  'Bangalore',
#  'Bangalore east',
#  'Banglore',
#  'Banswara',
#  'Banur',
#  'Bareilly',
#  'Bathinda',
#  'Bawal',
#  'Belgaum',
#  'Bellary',
#  'Bengaluru',
#  'Bengaluru (1) ',
#  'Bengaluru (12) ',
#  'Bengaluru (4th block jayanagar) ',
#  'Bengaluru (5th block koramangala) ',
#  'Bengaluru (6th block koramangala) ',
#  'Bengaluru (9th block jayanagar) ',
#  'Bengaluru (banashankari stage iii) ',
#  'Bengaluru (bommenahalli) ',
#  'Bengaluru (btm layout) ',
#  'Bengaluru (dasarahalli) ',
#  'Bengaluru (dodda nekkundi extension) ',
#  'Bengaluru (dodda nekkundi) ',
#  'Bengaluru (hosur road) ',
#  'Bengaluru (hsr layout) ',
#  'Bengaluru (indira nagar) ',
#  'Bengaluru (jakkur',
#  'Bengaluru (kengeri) ',
#  'Bengaluru (konanakunte) ',
#  'Bengaluru (kudlu) ',
#  'Bengaluru (malleshwaram) ',
#  'Bengaluru (marathahalli) ',
#  'Bengaluru (panathur) ',
#  'Bengaluru (sector 1 hsr layout',
#  'Bengaluru (sector 1 hsr layout) ',
#  'Bengaluru (sector 6 hsr layout) ',
#  'Bengaluru (vijay nagar',
#  'Bengaluru (whitefield) ',
#  'Bengaluru (wilson garden) ',
#  'Bengaluru / bangalore',
#  'Bharuch',
#  'Bhilai/bhillai',
#  'Bhiwadi',
#  'Bhiwani',
#  'Bhopal',
#  'Bhubaneshwar',
#  'Bijnor',
#  'Bikaner',
#  'Bina',
#  'Bokaro',
#  'Bommanahalli',
#  'Burdwan',
#  'Chakan',
#  'Chandigarh',
#  'Chandkheda) ',
#  'Chennai',
#  'Chennai cuddalore',
#  'Chennai kannur',
#  'Chennai pondichery',
#  'Chennai salem',
#  'Chennai thiruvallur',
#  'Chennai tirchy',
#  'Chennai vellore',
#  'Chennai villupuram',
#  'Chhindwara',
#  'Chinchwad',
#  'Chittoor',
#  'Churu',
#  'Coimbatore',
#  'Coimbatore madurai',
#  'Coimbatore tirchy',
#  'Coimbatore trichy',
#  'Cuddalore',
#  'Cuttack',
#  'Daman & diu',
#  'Dashrath puri',
#  'Davangere',
#  'Deccan gymkhana',
#  'Dehradun',
#  'Delhi',
#  'Delhi (1) ',
#  'Delhi (37) ',
#  'Delhi (netaji subhash place) ',
#  'Delhi (new moti nagar) ',
#  'Delhi (okhla',
#  'Delhi (okhla) ',
#  'Delhi (palam',
#  'Delhi (vikas puri) ',
#  'Delhi (yusuf sarai) ',
#  'Delhi ncr',
#  'Delhi ncr (192) ',
#  'Delhi ncr (197) ',
#  'Delhi ncr (198) ',
#  'Delhi ncr (199) ',
#  'Delhi ncr (ajmeri gate) ',
#  'Delhi ncr (connaught place) ',
#  'Delhi ncr (dhaula kuan) ',
#  'Delhi ncr (dilshad colony) ',
#  'Delhi ncr (jhandewalan) ',
#  'Delhi ncr (kalkaji) ',
#  'Delhi ncr (karampura',
#  'Delhi ncr (moti nagar',
#  'Delhi ncr (moti nagar) ',
#  'Delhi ncr (okhla) ',
#  'Delhi ncr (rohini',
#  'Delhi ncr (safdarjung enclave) ',
#  'Delhi ncr (sector-142 noida) ',
#  'Delhi ncr (sector-18 noida) ',
#  'Delhi ncr (sector-2 noida) ',
#  'Delhi ncr (sector-24 gurgaon) ',
#  'Delhi ncr (sector-63 gurgaon) ',
#  'Delhi ncr (sector-63 noida) ',
#  'Delhi ncr (shaheen bagh) ',
#  'Delhi ncr (shastri nagar) ',
#  'Delhi ncr (sohna road) ',
#  'Delhi ncr (south extension) ',
#  'Delhi ncr (vaishali) ',
#  'Deoghar',
#  'Dharuhera',
#  'Dibrugarh',
#  'Dindukul salem',
#  'Dubai/ uae',
#  'Durgapur',
#  'Erode',
#  'Erode madurai',
#  'Faizabad',
#  'Faridabad',
#  'Faridabad (ajronda chowk) ',
#  'Gandhidham',
#  'Gandhinagar',
#  'Gaya',
#  'Ghatkopar west',
#  'Ghaziabad',
#  'Ghaziabad (vaishali) ',
#  'Goa',
#  'Gorakhpur',
#  'Greater noida',
#  'Gujarat',
#  'Gujarat other',
#  'Gulbarga',
#  'Guna',
#  'Guntur',
#  'Gurdaspur',
#  'Gurgaon',
#  'Gurgaon (1) ',
#  'Gurgaon (2) ',
#  'Gurgaon (civil lines) ',
#  'Gurgaon (cyber city) ',
#  'Gurgaon (maruti vihar) ',
#  'Gurgaon (palam vihar) ',
#  'Gurgaon (sohna road) ',
#  'Gurgaon (udyog vihar) ',
#  'Guwahati',
#  'Hadapsar) ',
#  'Haldwani',
#  'Hardoi',
#  'Haryana',
#  'Hebbal) ',
#  'Hisar',
#  'Hong kong',
#  'Hosur',
#  'Hsr layout) ',
#  'Hubli',
#  'Hyderabad',
#  'Hyderabad (1) ',
#  'Hyderabad (bahadurpally) ',
#  'Hyderabad (banjara hills) ',
#  'Hyderabad (begumpet) ',
#  'Hyderabad (film nagar) ',
#  'Hyderabad (gachibowli) ',
#  'Hyderabad (jubilee hills) ',
#  'Hyderabad (kondapur) ',
#  'Hyderabad (lb nagar) ',
#  'Hyderabad (madhapur) ',
#  'Hyderabad (nanakramguda) ',
#  'Hyderabad (punjagutta) ',
#  'Hyderabad/secunderabad',
#  'Imphal',
#  'Indore',
#  'Itanagar',
#  'Jabalpur',
#  'Jaipur',
#  'Jalandhar',
#  'Jalgaon',
#  'Jalor',
#  'Jammu',
#  'Jamshedpur',
#  'Janakpuri',
#  'Jind',
#  'Jodhpur',
#  'Kalpakkam',
#  'Kancheepuram vellore',
#  'Kanchipuram',
#  'Kannur',
#  'Kanpur',
#  'Karimnagar',
#  'Karnal',
#  'Karur',
#  'Karur salem',
#  'Karve road',
#  'Katni',
#  'Katraj) ',
#  'Kerala',
#  'Kirti nagar industrial area',
#  'Kochi',
#  'Kolar',
#  'Kolha',
#  'Kolhapur',
#  'Kolkata',
#  'Kolkata (dalhousie) ',
#  'Kolkata (new town',
#  'Kolkata (rajarhat) ',
#  'Kolkata (salt lake) ',
#  'Kormangal',
#  'Kota',
#  'Kothrud',
#  'Kothrud) ',
#  'Kottayam',
#  'Kozhikode',
#  'Kumbakonam salem',
#  'Kurnool',
#  'Kurukshetra',
#  'Lake town',
#  'Lakshadweep',
#  'Lalitpur',
#  'Laxmi road) ',
#  'Lonavala',
#  'Lower parel) ',
#  'Lucknow',
#  'Ludhiana',
#  'Madurai',
#  'Madurai erode',
#  'Madurai trichy',
#  'Mahavir enclave) ',
#  'Makarpura) ',
#  'Malaysia',
#  'Mandsaur',
#  'Manesar',
#  'Mangalore',
#  'Maninagar',
#  'Mathura',
#  'Meerut',
#  'Moga',
#  'Mohali',
#  'Moradabad',
#  'Mulund',
#  'Mulund mumbai',
#  'Mumbai',
#  'Mumbai (airoli) ',
#  'Mumbai (chakala) ',
#  'Mumbai (charni road) ',
#  'Mumbai (diva gaon',
#  'Mumbai (dn nagar) ',
#  'Mumbai (film city road) ',
#  'Mumbai (lokhandwala) ',
#  'Mumbai (marol) ',
#  'Mumbai (mulund) ',
#  'Mumbai (mumbai central) ',
#  'Mumbai (parel',
#  'Mumbai (powai) ',
#  'Mumbai (rasayani) ',
#  'Mumbai (sector 1 ghansoli) ',
#  'Mumbai (shahapur) ',
#  'Mumbai (vikhroli) ',
#  'Mumbai (vishveshwar nagar) ',
#  'Mumbai pune',
#  'Mumbai suburbs',
#  'Mumbra',
#  'Murshidabad',
#  'Muzaffarpur',
#  'Mysore',
#  'Mysoru / mysore',
#  'Nagercoil',
#  'Nagercoil thuthukudi',
#  'Nagpur',
#  'Narol',
#  'Nasik',
#  'Navi mumbai',
#  'Nearby hometown',
#  'Nellore',
#  'New moti nagar) ',
#  'Nizamabad',
#  'Noida',
#  'Noida (1) ',
#  'Noida (sector-10 noida) ',
#  'Noida (sector-125 noida) ',
#  'Noida (sector-126 noida) ',
#  'Noida (sector-127 noida) ',
#  'Noida (sector-132 noida) ',
#  'Noida (sector-2 noida) ',
#  'Noida (sector-27 noida) ',
#  'Noida (sector-3 noida) ',
#  'Noida (sector-57 noida) ',
#  'Noida (sector-59 noida) ',
#  'Noida (sector-60 noida) ',
#  'Noida (sector-62 noida) ',
#  'Noida (sector-63 noida) ',
#  'Noida (sector-64 noida) ',
#  'Noida/greater noida',
#  'North hadapsar',
#  'Ooty',
#  'Orai',
#  'Other - other',
#  'Other city',
#  'Palakkad',
#  'Palanpur',
#  'Palej',
#  'Palwal',
#  'Pan india',
#  'Panchkula',
#  'Panipat',
#  'Panjim',
#  'Park street) ',
#  'Patiala',
#  'Patna',
#  'Patparganj industrial area) ',
#  'Pondicherry',
#  'Port blair',
#  'Pune',
#  'Pune (1) ',
#  'Pune (6) ',
#  'Pune (7) ',
#  'Pune (baner) ',
#  'Pune (budhwar peth',
#  'Pune (camp',
#  'Pune (chakan) ',
#  'Pune (dhayari) ',
#  'Pune (dhole patil road) ',
#  'Pune (hadapsar gaon',
#  'Pune (kalyani nagar) ',
#  'Pune (mukund nagar) ',
#  'Pune (pimpri) ',
#  'Pune (pune nashik highway) ',
#  'Pune (ranjangaon',
#  'Pune (sector no-7 bhosari) ',
#  'Pune (senapati bapat road) ',
#  'Pune (shivaji nagar',
#  'Pune (shivaji nagar) ',
#  'Pune (viman nagar',
#  'Pune (viman nagar) ',
#  'Pune (wagholi) ',
#  'Qatar',
#  'Raigad',
#  'Raigarh',
#  'Raipur',
#  'Rajahmundry',
#  'Rajkot',
#  'Rakhial',
#  'Rancharda) ',
#  'Ranchi',
#  'Rewari',
#  'Rohtak',
#  'Roorkee',
#  'Ropar',
#  'Safdarjung enclave) ',
#  'Sagar',
#  'Saharanpur',
#  'Salem',
#  'Salem bangalore',
#  'Salem erode',
#  'Salem nagercoil',
#  'Salem trichy',
#  'Salt lake',
#  'Satara',
#  'Sector no-7 bhosari',
#  'Sector-24 gurgaon',
#  'Shimla',
#  'Shiva nagar',
#  'Shivaji marg',
#  'Shivaji nagar',
#  'Shyamal',
#  'Sinthee',
#  'Solapur',
#  'Sonepat',
#  'Srinagar',
#  'Surat',
#  'Surendranagar',
#  'Talegaon) ',
#  'Tata silk farm) ',
#  'Thane',
#  'Thanjavur',
#  'Thrissur',
#  'Tilak nagar',
#  'Tirunelveli',
#  'Tirupati',
#  'Tirupur',
#  'Trichy',
#  'Trivandrum',
#  'Tumkur',
#  'Tuticorin',
#  'Udaipur',
#  'Udyog vihar) ',
#  'Ujjain',
#  'Vadodara',
#  'Vapi',
#  'Varanasi',
#  'Vasai',
#  'Vasco da gama',
#  'Vellore',
#  'Vellore madurai',
#  'Vellore salem',
#  'Vellore trichy',
#  'Vijayanagar) ',
#  'Vijayawada',
#  'Vikhroli) ',
#  'Visakhapatnam',
#  'Warangal',
#  'Yamunanagar',
#  'Yerwada) ']

# %%
jobsInCity = []
city = "Noida"
for i in range (len(df)):
    if city in df.iloc[i]['Location']:
        jobsInCity.append(df.iloc[i]) 
#jobsInCity is a list of all the jobs in the city

# %%
rolesInCity = {}
for i in range (len(jobsInCity)):
    if (jobsInCity[i]['Role'] in rolesInCity):
        rolesInCity[jobsInCity[i]['Role']] += 1
    else:
        rolesInCity[jobsInCity[i]['Role']] = 1
#rolesInCity is a list of all the roles in the chosen city

# %%
role = "Software Developer"
jobs = []
for i in range (len(jobsInCity)):
    if role in jobsInCity[i]['Role']:
        jobs.append(jobsInCity[i])
# jobs is all the jobs of the chosen role in the chosen city

# %%
len(jobs)
# Out:
# 22
